# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("movies_500.csv")

# %%
df.head()
# Out:
#    movie_id           title          genres  \
# 0         1  Shadow Journey           Drama
# 1         2   Shadow Empire           Drama
# 2         3   Shadow Legacy   Romance|Drama
# 3         4  Shadow Promise   Action|Sci-Fi
# 4         5    Shadow Storm  Horror|Mystery
#
#                                             overview
# 0  An unexpected discovery changes the lives of e...
# 1  A heartfelt journey explores friendship, coura...
# 2  An unexpected discovery changes the lives of e...
# 3  An unexpected discovery changes the lives of e...
# 4  An unexpected discovery changes the lives of e...

# %%
df.shape
# Out:
# (500, 4)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  500 non-null    int64
#  1   title     500 non-null    str
#  2   genres    500 non-null    str
#  3   overview  500 non-null    str
# dtypes: int64(1), str(3)
# memory usage: 62.2 KB

# %%
df.isnull().sum()
# Out:
# movie_id    0
# title       0
# genres      0
# overview    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("clean_movies.csv", index=False)
